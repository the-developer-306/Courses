# %% [markdown]
# # L6: Building Your Crew for Production

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Creating a new project

# %%
! crewai create crew new_project --provider openai
# Out:
# Creating folder new_project...
#   - Created new_project/.gitignore
#   - Created new_project/pyproject.toml
#   - Created new_project/README.md
#   - Created new_project/src/new_project/__init__.py
#   - Created new_project/src/new_project/main.py
#   - Created new_project/src/new_project/crew.py
#   - Created new_project/src/new_project/tools/custom_tool.py
#   - Created new_project/src/new_project/tools/__init__.py
#   - Created new_project/src/new_project/config/agents.yaml
#   - Created new_project/src/new_project/config/tasks.yaml
# Crew new_project created successfully!

# %% [markdown]
# ## Setting up the Environment

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note</code>:</b> The following line might take a few minutes to finish.</p>

# %%
! cd new_project && crewai install
# Out:
# Using CPython 3.11.9 interpreter at: /usr/local/bin/python
# Creating virtual environment at: .venv
# Resolved 244 packages in 1.77s
# Building new-project @ file:///home/jovyan/work/L13/new_project
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/238)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/238)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/238)
# pydantic-core ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/238)
# jedi       ------------------------------     0 B/1.50 MiB
# pydantic-core ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/238)
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# pydantic-core ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/238)
# ipython    ------------------------------     0 B/802.33 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# pydantic-core ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/238)
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/802.33 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# pydantic-core ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/238)
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/802.33 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# pydantic-core ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/238)
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/802.33 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# pydantic-core ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/238)
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/802.33 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# pydantic-core ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/238)
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/802.33 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# pydantic-core ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/238)
# httptools  ------------------------------     0 B/449.01 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/802.33 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# pydantic-core ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/238)
# openai     ------------------------------     0 B/445.42 KiB
# httptools  ------------------------------     0 B/449.01 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/802.33 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# pydantic-core ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/238)
# huggingface-hub ------------------------------     0 B/440.10 KiB
# openai     ------------------------------     0 B/445.42 KiB
# httptools  ------------------------------     0 B/449.01 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/802.33 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# pydantic-core ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/238)
# huggingface-hub ------------------------------     0 B/440.10 KiB
# openai     ------------------------------     0 B/445.42 KiB
# httptools  ------------------------------     0 B/449.01 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/802.33 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# pydantic-core ------------------------------ 14.91 KiB/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/238)
# huggingface-hub ------------------------------     0 B/440.10 KiB
# openai     ------------------------------     0 B/445.42 KiB
# httptools  ------------------------------     0 B/449.01 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/802.33 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------ 14.88 KiB/1.50 MiB
# pydantic-core ------------------------------ 14.91 KiB/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/238)
# huggingface-hub ------------------------------ 46.77 KiB/440.10 KiB
# watchfiles ------------------------------ 30.92 KiB/441.97 KiB
# openai     ------------------------------ 29.42 KiB/445.42 KiB
# httptools  ------------------------------ 78.91 KiB/449.01 KiB
# cffi       ------------------------------ 72.74 KiB/456.29 KiB
# trio       ------------------------------ 15.89 KiB/474.92 KiB
# pytz       ------------------------------ 30.88 KiB/496.10 KiB
# mpmath     ------------------------------ 94.85 KiB/523.63 KiB
# crewai-tools ------------------------------ 8.63 KiB/524.67 KiB
# greenlet   ------------------------------ 46.91 KiB/588.29 KiB
# chromadb   ------------------------------ 16.00 KiB/613.62 KiB
# pyvis      ------------------------------ 14.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 30.88 KiB/745.07 KiB
# regex      ------------------------------ 16.00 KiB/774.15 KiB
# ipython    ------------------------------ 62.88 KiB/802.33 KiB
# langchain  ------------------------------ 14.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 14.91 KiB/1.03 MiB
# pygments   ------------------------------ 30.88 KiB/1.17 MiB
# snowflake-core ------------------------------ 30.91 KiB/1.48 MiB
# jedi       ------------------------------ 46.88 KiB/1.50 MiB
# aiohttp    ------------------------------ 30.88 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/238)
# huggingface-hub ------------------------------ 46.77 KiB/440.10 KiB
# watchfiles ------------------------------ 30.92 KiB/441.97 KiB
# openai     ------------------------------ 45.42 KiB/445.42 KiB
# httptools  ------------------------------ 126.91 KiB/449.01 KiB
# cffi       ------------------------------ 120.74 KiB/456.29 KiB
# trio       ------------------------------ 47.89 KiB/474.92 KiB
# pytz       ------------------------------ 30.88 KiB/496.10 KiB
# mpmath     ------------------------------ 126.85 KiB/523.63 KiB
# crewai-tools ------------------------------ 14.92 KiB/524.67 KiB
# greenlet   ------------------------------ 46.91 KiB/588.29 KiB
# chromadb   ------------------------------ 16.00 KiB/613.62 KiB
# pyvis      ------------------------------ 30.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 46.88 KiB/745.07 KiB
# regex      ------------------------------ 144.00 KiB/774.15 KiB
# ipython    ------------------------------ 94.88 KiB/802.33 KiB
# langchain  ------------------------------ 14.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 14.91 KiB/1.03 MiB
# pygments   ------------------------------ 62.78 KiB/1.17 MiB
# snowflake-core ------------------------------ 30.91 KiB/1.48 MiB
# jedi       ------------------------------ 62.78 KiB/1.50 MiB
# aiohttp    ------------------------------ 46.88 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/238)
# huggingface-hub ------------------------------ 172.75 KiB/440.10 KiB
# watchfiles ------------------------------ 222.92 KiB/441.97 KiB
# openai     ------------------------------ 61.42 KiB/445.42 KiB
# httptools  ------------------------------ 238.46 KiB/449.01 KiB
# cffi       ------------------------------ 232.74 KiB/456.29 KiB
# trio       ------------------------------ 93.88 KiB/474.92 KiB
# pytz       ------------------------------ 46.88 KiB/496.10 KiB
# mpmath     ------------------------------ 190.63 KiB/523.63 KiB
# crewai-tools ------------------------------ 30.81 KiB/524.67 KiB
# greenlet   ------------------------------ 78.46 KiB/588.29 KiB
# chromadb   ------------------------------ 63.89 KiB/613.62 KiB
# pyvis      ------------------------------ 206.65 KiB/738.32 KiB
# pyyaml     ------------------------------ 218.89 KiB/745.07 KiB
# regex      ------------------------------ 209.21 KiB/774.15 KiB
# ipython    ------------------------------ 126.88 KiB/802.33 KiB
# langchain  ------------------------------ 30.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 190.91 KiB/1.03 MiB
# pygments   ------------------------------ 94.08 KiB/1.17 MiB
# snowflake-core ------------------------------ 46.91 KiB/1.48 MiB
# jedi       ------------------------------ 91.06 KiB/1.50 MiB
# aiohttp    ------------------------------ 94.88 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/238)
# huggingface-hub ------------------------------ 236.75 KiB/440.10 KiB
# watchfiles ------------------------------ 295.58 KiB/441.97 KiB
# openai     ------------------------------ 77.42 KiB/445.42 KiB
# httptools  ------------------------------ 302.91 KiB/449.01 KiB
# cffi       ------------------------------ 312.74 KiB/456.29 KiB
# trio       ------------------------------ 141.88 KiB/474.92 KiB
# pytz       ------------------------------ 46.88 KiB/496.10 KiB
# mpmath     ------------------------------ 264.74 KiB/523.63 KiB
# crewai-tools ------------------------------ 30.81 KiB/524.67 KiB
# greenlet   ------------------------------ 273.34 KiB/588.29 KiB
# chromadb   ------------------------------ 79.89 KiB/613.62 KiB
# pyvis      ------------------------------ 254.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 270.89 KiB/745.07 KiB
# regex      ------------------------------ 288.00 KiB/774.15 KiB
# ipython    ------------------------------ 238.88 KiB/802.33 KiB
# langchain  ------------------------------ 30.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 270.91 KiB/1.03 MiB
# pygments   ------------------------------ 174.08 KiB/1.17 MiB
# snowflake-core ------------------------------ 78.91 KiB/1.48 MiB
# jedi       ------------------------------ 126.13 KiB/1.50 MiB
# aiohttp    ------------------------------ 276.00 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/238)
# huggingface-hub ------------------------------ 316.75 KiB/440.10 KiB
# watchfiles ------------------------------ 369.05 KiB/441.97 KiB
# openai     ------------------------------ 77.42 KiB/445.42 KiB
# httptools  ------------------------------ 392.56 KiB/449.01 KiB
# cffi       ------------------------------ 392.74 KiB/456.29 KiB
# trio       ------------------------------ 189.88 KiB/474.92 KiB
# pytz       ------------------------------ 92.20 KiB/496.10 KiB
# mpmath     ------------------------------ 356.45 KiB/523.63 KiB
# crewai-tools ------------------------------ 48.48 KiB/524.67 KiB
# greenlet   ------------------------------ 350.46 KiB/588.29 KiB
# chromadb   ------------------------------ 111.79 KiB/613.62 KiB
# pyvis      ------------------------------ 334.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 350.89 KiB/745.07 KiB
# regex      ------------------------------ 383.89 KiB/774.15 KiB
# ipython    ------------------------------ 302.88 KiB/802.33 KiB
# langchain  ------------------------------ 46.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 344.53 KiB/1.03 MiB
# pygments   ------------------------------ 334.08 KiB/1.17 MiB
# snowflake-core ------------------------------ 110.91 KiB/1.48 MiB
# jedi       ------------------------------ 170.96 KiB/1.50 MiB
# aiohttp    ------------------------------ 350.88 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/238)
# huggingface-hub ------------------------------ 332.75 KiB/440.10 KiB
# watchfiles ------------------------------ 424.56 KiB/441.97 KiB
# openai     ------------------------------ 110.20 KiB/445.42 KiB
# cffi       ------------------------------ 456.29 KiB/456.29 KiB
# trio       ------------------------------ 253.88 KiB/474.92 KiB
# pytz       ------------------------------ 108.20 KiB/496.10 KiB
# mpmath     ------------------------------ 408.74 KiB/523.63 KiB
# crewai-tools ------------------------------ 94.92 KiB/524.67 KiB
# greenlet   ------------------------------ 414.46 KiB/588.29 KiB
# chromadb   ------------------------------ 368.00 KiB/613.62 KiB
# pyvis      ------------------------------ 392.56 KiB/738.32 KiB
# pyyaml     ------------------------------ 414.89 KiB/745.07 KiB
# regex      ------------------------------ 431.78 KiB/774.15 KiB
# ipython    ------------------------------ 350.88 KiB/802.33 KiB
# langchain  ------------------------------ 46.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 392.56 KiB/1.03 MiB
# pygments   ------------------------------ 366.08 KiB/1.17 MiB
# snowflake-core ------------------------------ 142.91 KiB/1.48 MiB
# jedi       ------------------------------ 202.85 KiB/1.50 MiB
# aiohttp    ------------------------------ 398.88 KiB/1.60 MiB
# networkx   ------------------------------ 238.88 KiB/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/238)
# pydantic   ------------------------------     0 B/421.58 KiB
# huggingface-hub ------------------------------ 332.75 KiB/440.10 KiB
# watchfiles ------------------------------ 440.56 KiB/441.97 KiB
# openai     ------------------------------ 110.20 KiB/445.42 KiB
# cffi       ------------------------------ 456.29 KiB/456.29 KiB
# trio       ------------------------------ 301.88 KiB/474.92 KiB
# pytz       ------------------------------ 108.20 KiB/496.10 KiB
# mpmath     ------------------------------ 424.74 KiB/523.63 KiB
# crewai-tools ------------------------------ 94.92 KiB/524.67 KiB
# greenlet   ------------------------------ 446.46 KiB/588.29 KiB
# chromadb   ------------------------------ 368.00 KiB/613.62 KiB
# pyvis      ------------------------------ 423.88 KiB/738.32 KiB
# pyyaml     ------------------------------ 444.02 KiB/745.07 KiB
# regex      ------------------------------ 447.78 KiB/774.15 KiB
# ipython    ------------------------------ 350.88 KiB/802.33 KiB
# langchain  ------------------------------ 46.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 405.40 KiB/1.03 MiB
# pygments   ------------------------------ 398.08 KiB/1.17 MiB
# snowflake-core ------------------------------ 158.91 KiB/1.48 MiB
# jedi       ------------------------------ 219.06 KiB/1.50 MiB
# aiohttp    ------------------------------ 414.88 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/238)
# pydantic   ------------------------------     0 B/421.58 KiB
# huggingface-hub ------------------------------ 332.75 KiB/440.10 KiB
# watchfiles ------------------------------ 440.56 KiB/441.97 KiB
# openai     ------------------------------ 110.20 KiB/445.42 KiB
# trio       ------------------------------ 301.88 KiB/474.92 KiB
# pytz       ------------------------------ 108.20 KiB/496.10 KiB
# mpmath     ------------------------------ 424.74 KiB/523.63 KiB
# crewai-tools ------------------------------ 94.92 KiB/524.67 KiB
# greenlet   ------------------------------ 446.46 KiB/588.29 KiB
# chromadb   ------------------------------ 368.00 KiB/613.62 KiB
# pyvis      ------------------------------ 423.88 KiB/738.32 KiB
# pyyaml     ------------------------------ 444.02 KiB/745.07 KiB
# regex      ------------------------------ 447.78 KiB/774.15 KiB
# ipython    ------------------------------ 366.88 KiB/802.33 KiB
# langchain  ------------------------------ 46.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 405.40 KiB/1.03 MiB
# pygments   ------------------------------ 398.08 KiB/1.17 MiB
# snowflake-core ------------------------------ 158.91 KiB/1.48 MiB
# jedi       ------------------------------ 219.06 KiB/1.50 MiB
# aiohttp    ------------------------------ 414.88 KiB/1.60 MiB
# networkx   ------------------------------ 254.88 KiB/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/238)
# pydantic   ------------------------------ 15.30 KiB/421.58 KiB
# huggingface-hub ------------------------------ 348.75 KiB/440.10 KiB
# openai     ------------------------------ 126.20 KiB/445.42 KiB
# trio       ------------------------------ 301.88 KiB/474.92 KiB
# pytz       ------------------------------ 108.20 KiB/496.10 KiB
# mpmath     ------------------------------ 424.74 KiB/523.63 KiB
# crewai-tools ------------------------------ 325.28 KiB/524.67 KiB
# greenlet   ------------------------------ 462.46 KiB/588.29 KiB
# chromadb   ------------------------------ 368.00 KiB/613.62 KiB
# pyvis      ------------------------------ 439.88 KiB/738.32 KiB
# pyyaml     ------------------------------ 460.02 KiB/745.07 KiB
# regex      ------------------------------ 464.00 KiB/774.15 KiB
# ipython    ------------------------------ 366.88 KiB/802.33 KiB
# langchain  ------------------------------ 46.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 437.40 KiB/1.03 MiB
# pygments   ------------------------------ 398.08 KiB/1.17 MiB
# snowflake-core ------------------------------ 158.91 KiB/1.48 MiB
# jedi       ------------------------------ 235.18 KiB/1.50 MiB
# aiohttp    ------------------------------ 441.25 KiB/1.60 MiB
# networkx   ------------------------------ 270.88 KiB/1.64 MiB
# kubernetes ------------------------------ 472.56 KiB/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/238)
# prompt-toolkit ------------------------------ 48.00 KiB/378.73 KiB
# langchain-core ------------------------------ 32.00 KiB/402.55 KiB
# pydantic   ------------------------------ 73.87 KiB/421.58 KiB
# huggingface-hub ------------------------------ 393.25 KiB/440.10 KiB
# openai     ------------------------------ 158.20 KiB/445.42 KiB
# trio       ------------------------------ 333.88 KiB/474.92 KiB
# pytz       ------------------------------ 124.09 KiB/496.10 KiB
# mpmath     ------------------------------ 504.74 KiB/523.63 KiB
# crewai-tools ------------------------------ 461.40 KiB/524.67 KiB
# greenlet   ------------------------------ 542.46 KiB/588.29 KiB
# chromadb   ------------------------------ 400.00 KiB/613.62 KiB
# pyvis      ------------------------------ 488.62 KiB/738.32 KiB
# pyyaml     ------------------------------ 522.24 KiB/745.07 KiB
# regex      ------------------------------ 539.04 KiB/774.15 KiB
# ipython    ------------------------------ 408.56 KiB/802.33 KiB
# langchain  ------------------------------ 62.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 504.56 KiB/1.03 MiB
# pygments   ------------------------------ 478.08 KiB/1.17 MiB
# snowflake-core ------------------------------ 190.91 KiB/1.48 MiB
# jedi       ------------------------------ 235.18 KiB/1.50 MiB
# aiohttp    ------------------------------ 510.78 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/238)
# prompt-toolkit ------------------------------ 64.00 KiB/378.73 KiB
# langchain-core ------------------------------ 48.00 KiB/402.55 KiB
# pydantic   ------------------------------ 105.87 KiB/421.58 KiB
# huggingface-hub ------------------------------ 412.75 KiB/440.10 KiB
# openai     ------------------------------ 198.66 KiB/445.42 KiB
# trio       ------------------------------ 365.88 KiB/474.92 KiB
# pytz       ------------------------------ 124.09 KiB/496.10 KiB
# crewai-tools ------------------------------ 477.40 KiB/524.67 KiB
# greenlet   ------------------------------ 558.46 KiB/588.29 KiB
# chromadb   ------------------------------ 416.00 KiB/613.62 KiB
# pyvis      ------------------------------ 520.56 KiB/738.32 KiB
# pyyaml     ------------------------------ 542.89 KiB/745.07 KiB
# regex      ------------------------------ 571.04 KiB/774.15 KiB
# ipython    ------------------------------ 440.56 KiB/802.33 KiB
# langchain  ------------------------------ 62.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 536.56 KiB/1.03 MiB
# pygments   ------------------------------ 510.08 KiB/1.17 MiB
# snowflake-core ------------------------------ 206.91 KiB/1.48 MiB
# jedi       ------------------------------ 252.24 KiB/1.50 MiB
# aiohttp    ------------------------------ 526.88 KiB/1.60 MiB
# networkx   ------------------------------ 302.88 KiB/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/238)
# google-cloud-resource-manager ------------------------------ 16.00 KiB/375.13 KiB
# prompt-toolkit ------------------------------ 96.00 KiB/378.73 KiB
# langchain-core ------------------------------ 64.00 KiB/402.55 KiB
# pydantic   ------------------------------ 125.55 KiB/421.58 KiB
# openai     ------------------------------ 206.20 KiB/445.42 KiB
# trio       ------------------------------ 413.88 KiB/474.92 KiB
# pytz       ------------------------------ 124.09 KiB/496.10 KiB
# crewai-tools ------------------------------ 493.40 KiB/524.67 KiB
# greenlet   ------------------------------ 558.46 KiB/588.29 KiB
# chromadb   ------------------------------ 432.00 KiB/613.62 KiB
# pyvis      ------------------------------ 553.73 KiB/738.32 KiB
# pyyaml     ------------------------------ 590.89 KiB/745.07 KiB
# regex      ------------------------------ 592.00 KiB/774.15 KiB
# ipython    ------------------------------ 475.46 KiB/802.33 KiB
# langchain  ------------------------------ 78.81 KiB/985.93 KiB
# tiktoken   ------------------------------ 555.56 KiB/1.03 MiB
# pygments   ------------------------------ 558.08 KiB/1.17 MiB
# snowflake-core ------------------------------ 238.91 KiB/1.48 MiB
# jedi       ------------------------------ 252.24 KiB/1.50 MiB
# aiohttp    ------------------------------ 574.88 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/238)
# rpds-py    ------------------------------     0 B/372.36 KiB
# google-cloud-resource-manager ------------------------------ 16.00 KiB/375.13 KiB
# prompt-toolkit ------------------------------ 96.00 KiB/378.73 KiB
# langchain-core ------------------------------ 64.00 KiB/402.55 KiB
# pydantic   ------------------------------ 141.55 KiB/421.58 KiB
# openai     ------------------------------ 222.20 KiB/445.42 KiB
# trio       ------------------------------ 429.88 KiB/474.92 KiB
# pytz       ------------------------------ 124.09 KiB/496.10 KiB
# crewai-tools ------------------------------ 493.40 KiB/524.67 KiB
# greenlet   ------------------------------ 567.29 KiB/588.29 KiB
# chromadb   ------------------------------ 448.00 KiB/613.62 KiB
# pyvis      ------------------------------ 569.73 KiB/738.32 KiB
# pyyaml     ------------------------------ 606.89 KiB/745.07 KiB
# regex      ------------------------------ 624.00 KiB/774.15 KiB
# ipython    ------------------------------ 475.46 KiB/802.33 KiB
# langchain  ------------------------------ 78.81 KiB/985.93 KiB
# tiktoken   ------------------------------ 584.56 KiB/1.03 MiB
# pygments   ------------------------------ 558.08 KiB/1.17 MiB
# snowflake-core ------------------------------ 254.91 KiB/1.48 MiB
# jedi       ------------------------------ 252.24 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/238)
# rpds-py    ------------------------------ 62.59 KiB/372.36 KiB
# google-cloud-resource-manager ------------------------------ 93.06 KiB/375.13 KiB
# prompt-toolkit ------------------------------ 118.59 KiB/378.73 KiB
# langchain-core ------------------------------ 112.00 KiB/402.55 KiB
# pydantic   ------------------------------ 189.55 KiB/421.58 KiB
# openai     ------------------------------ 237.84 KiB/445.42 KiB
# trio       ------------------------------ 461.88 KiB/474.92 KiB
# pytz       ------------------------------ 140.09 KiB/496.10 KiB
# crewai-tools ------------------------------ 509.40 KiB/524.67 KiB
# chromadb   ------------------------------ 480.00 KiB/613.62 KiB
# pyvis      ------------------------------ 634.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 686.89 KiB/745.07 KiB
# regex      ------------------------------ 688.00 KiB/774.15 KiB
# ipython    ------------------------------ 568.56 KiB/802.33 KiB
# langchain  ------------------------------ 110.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 648.56 KiB/1.03 MiB
# pygments   ------------------------------ 638.08 KiB/1.17 MiB
# snowflake-core ------------------------------ 286.91 KiB/1.48 MiB
# jedi       ------------------------------ 267.06 KiB/1.50 MiB
# aiohttp    ------------------------------ 654.88 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/238)
# rpds-py    ------------------------------ 62.59 KiB/372.36 KiB
# google-cloud-resource-manager ------------------------------ 109.06 KiB/375.13 KiB
# prompt-toolkit ------------------------------ 128.00 KiB/378.73 KiB
# langchain-core ------------------------------ 128.00 KiB/402.55 KiB
# pydantic   ------------------------------ 221.55 KiB/421.58 KiB
# openai     ------------------------------ 237.84 KiB/445.42 KiB
# trio       ------------------------------ 461.88 KiB/474.92 KiB
# pytz       ------------------------------ 140.09 KiB/496.10 KiB
# chromadb   ------------------------------ 480.00 KiB/613.62 KiB
# pyvis      ------------------------------ 634.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 702.89 KiB/745.07 KiB
# regex      ------------------------------ 704.00 KiB/774.15 KiB
# ipython    ------------------------------ 584.56 KiB/802.33 KiB
# langchain  ------------------------------ 110.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 664.56 KiB/1.03 MiB
# pygments   ------------------------------ 654.08 KiB/1.17 MiB
# snowflake-core ------------------------------ 286.91 KiB/1.48 MiB
# jedi       ------------------------------ 267.06 KiB/1.50 MiB
# aiohttp    ------------------------------ 654.88 KiB/1.60 MiB
# networkx   ------------------------------ 392.56 KiB/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/238)
# rpds-py    ------------------------------ 62.59 KiB/372.36 KiB
# google-cloud-resource-manager ------------------------------ 109.06 KiB/375.13 KiB
# prompt-toolkit ------------------------------ 128.00 KiB/378.73 KiB
# langchain-core ------------------------------ 128.00 KiB/402.55 KiB
# pydantic   ------------------------------ 221.55 KiB/421.58 KiB
# openai     ------------------------------ 237.84 KiB/445.42 KiB
# trio       ------------------------------ 474.92 KiB/474.92 KiB
# pytz       ------------------------------ 140.09 KiB/496.10 KiB
# chromadb   ------------------------------ 480.00 KiB/613.62 KiB
# pyvis      ------------------------------ 634.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 702.89 KiB/745.07 KiB
# regex      ------------------------------ 704.00 KiB/774.15 KiB
# ipython    ------------------------------ 584.56 KiB/802.33 KiB
# langchain  ------------------------------ 110.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 664.56 KiB/1.03 MiB
# pygments   ------------------------------ 654.08 KiB/1.17 MiB
# snowflake-core ------------------------------ 286.91 KiB/1.48 MiB
# jedi       ------------------------------ 267.06 KiB/1.50 MiB
# aiohttp    ------------------------------ 654.88 KiB/1.60 MiB
# networkx   ------------------------------ 392.56 KiB/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/238)
# rpds-py    ------------------------------ 62.59 KiB/372.36 KiB
# google-cloud-resource-manager ------------------------------ 120.86 KiB/375.13 KiB
# prompt-toolkit ------------------------------ 128.00 KiB/378.73 KiB
# langchain-core ------------------------------ 144.00 KiB/402.55 KiB
# pydantic   ------------------------------ 237.55 KiB/421.58 KiB
# openai     ------------------------------ 237.84 KiB/445.42 KiB
# pytz       ------------------------------ 140.09 KiB/496.10 KiB
# chromadb   ------------------------------ 480.00 KiB/613.62 KiB
# pyvis      ------------------------------ 634.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 702.89 KiB/745.07 KiB
# regex      ------------------------------ 704.00 KiB/774.15 KiB
# ipython    ------------------------------ 584.56 KiB/802.33 KiB
# langchain  ------------------------------ 110.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 664.56 KiB/1.03 MiB
# pygments   ------------------------------ 654.08 KiB/1.17 MiB
# snowflake-core ------------------------------ 286.91 KiB/1.48 MiB
# jedi       ------------------------------ 267.06 KiB/1.50 MiB
# aiohttp    ------------------------------ 654.88 KiB/1.60 MiB
# networkx   ------------------------------ 392.56 KiB/1.64 MiB
# kubernetes ------------------------------ 632.56 KiB/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/238)
# yarl       ------------------------------ 32.00 KiB/336.08 KiB
# jiter      ------------------------------ 48.00 KiB/337.45 KiB
# tzdata     ------------------------------ 14.88 KiB/338.63 KiB
# rpds-py    ------------------------------ 126.59 KiB/372.36 KiB
# google-cloud-resource-manager ------------------------------ 167.70 KiB/375.13 KiB
# prompt-toolkit ------------------------------ 192.00 KiB/378.73 KiB
# langchain-core ------------------------------ 176.00 KiB/402.55 KiB
# pydantic   ------------------------------ 285.55 KiB/421.58 KiB
# openai     ------------------------------ 253.84 KiB/445.42 KiB
# pytz       ------------------------------ 172.20 KiB/496.10 KiB
# chromadb   ------------------------------ 496.00 KiB/613.62 KiB
# pyvis      ------------------------------ 712.56 KiB/738.32 KiB
# regex      ------------------------------ 768.00 KiB/774.15 KiB
# ipython    ------------------------------ 636.32 KiB/802.33 KiB
# langchain  ------------------------------ 126.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 728.56 KiB/1.03 MiB
# pygments   ------------------------------ 830.08 KiB/1.17 MiB
# snowflake-core ------------------------------ 350.91 KiB/1.48 MiB
# jedi       ------------------------------ 271.06 KiB/1.50 MiB
# aiohttp    ------------------------------ 734.88 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/238)
# yarl       ------------------------------ 48.00 KiB/336.08 KiB
# jiter      ------------------------------ 48.00 KiB/337.45 KiB
# tzdata     ------------------------------ 14.88 KiB/338.63 KiB
# rpds-py    ------------------------------ 126.59 KiB/372.36 KiB
# google-cloud-resource-manager ------------------------------ 183.59 KiB/375.13 KiB
# prompt-toolkit ------------------------------ 192.00 KiB/378.73 KiB
# langchain-core ------------------------------ 176.00 KiB/402.55 KiB
# pydantic   ------------------------------ 285.55 KiB/421.58 KiB
# openai     ------------------------------ 253.84 KiB/445.42 KiB
# pytz       ------------------------------ 172.20 KiB/496.10 KiB
# chromadb   ------------------------------ 496.00 KiB/613.62 KiB
# pyvis      ------------------------------ 712.56 KiB/738.32 KiB
# ipython    ------------------------------ 648.56 KiB/802.33 KiB
# langchain  ------------------------------ 126.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 744.56 KiB/1.03 MiB
# pygments   ------------------------------ 846.08 KiB/1.17 MiB
# snowflake-core ------------------------------ 350.91 KiB/1.48 MiB
# jedi       ------------------------------ 271.06 KiB/1.50 MiB
# aiohttp    ------------------------------ 734.88 KiB/1.60 MiB
# networkx   ------------------------------ 440.56 KiB/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/238)
# yarl       ------------------------------ 63.75 KiB/336.08 KiB
# jiter      ------------------------------ 61.74 KiB/337.45 KiB
# tzdata     ------------------------------ 14.88 KiB/338.63 KiB
# rpds-py    ------------------------------ 135.70 KiB/372.36 KiB
# google-cloud-resource-manager ------------------------------ 183.59 KiB/375.13 KiB
# prompt-toolkit ------------------------------ 192.00 KiB/378.73 KiB
# langchain-core ------------------------------ 192.00 KiB/402.55 KiB
# pydantic   ------------------------------ 301.55 KiB/421.58 KiB
# openai     ------------------------------ 253.84 KiB/445.42 KiB
# pytz       ------------------------------ 172.20 KiB/496.10 KiB
# chromadb   ------------------------------ 496.00 KiB/613.62 KiB
# pyvis      ------------------------------ 728.56 KiB/738.32 KiB
# ipython    ------------------------------ 648.56 KiB/802.33 KiB
# langchain  ------------------------------ 126.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 744.56 KiB/1.03 MiB
# pygments   ------------------------------ 846.08 KiB/1.17 MiB
# snowflake-core ------------------------------ 366.91 KiB/1.48 MiB
# jedi       ------------------------------ 271.06 KiB/1.50 MiB
# aiohttp    ------------------------------ 750.88 KiB/1.60 MiB
# networkx   ------------------------------ 440.56 KiB/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/238)
# protobuf   ------------------------------ 32.00 KiB/312.18 KiB
# weaviate-client ------------------------------ 16.00 KiB/322.71 KiB
# yarl       ------------------------------ 111.19 KiB/336.08 KiB
# jiter      ------------------------------ 109.63 KiB/337.45 KiB
# tzdata     ------------------------------ 30.88 KiB/338.63 KiB
# rpds-py    ------------------------------ 183.70 KiB/372.36 KiB
# google-cloud-resource-manager ------------------------------ 206.79 KiB/375.13 KiB
# prompt-toolkit ------------------------------ 256.00 KiB/378.73 KiB
# langchain-core ------------------------------ 265.81 KiB/402.55 KiB
# pydantic   ------------------------------ 349.55 KiB/421.58 KiB
# openai     ------------------------------ 253.84 KiB/445.42 KiB
# pytz       ------------------------------ 172.20 KiB/496.10 KiB
# chromadb   ------------------------------ 544.00 KiB/613.62 KiB
# ipython    ------------------------------ 680.56 KiB/802.33 KiB
# langchain  ------------------------------ 142.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 776.56 KiB/1.03 MiB
# pygments   ------------------------------ 894.08 KiB/1.17 MiB
# snowflake-core ------------------------------ 389.12 KiB/1.48 MiB
# jedi       ------------------------------ 287.06 KiB/1.50 MiB
# aiohttp    ------------------------------ 798.88 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/238)
# langsmith  ------------------------------ 16.00 KiB/304.50 KiB
# protobuf   ------------------------------ 53.67 KiB/312.18 KiB
# weaviate-client ------------------------------ 36.16 KiB/322.71 KiB
# yarl       ------------------------------ 127.75 KiB/336.08 KiB
# jiter      ------------------------------ 125.74 KiB/337.45 KiB
# tzdata     ------------------------------ 77.54 KiB/338.63 KiB
# rpds-py    ------------------------------ 206.59 KiB/372.36 KiB
# google-cloud-resource-manager ------------------------------ 270.79 KiB/375.13 KiB
# prompt-toolkit ------------------------------ 288.00 KiB/378.73 KiB
# langchain-core ------------------------------ 297.81 KiB/402.55 KiB
# pydantic   ------------------------------ 397.55 KiB/421.58 KiB
# openai     ------------------------------ 269.84 KiB/445.42 KiB
# pytz       ------------------------------ 188.20 KiB/496.10 KiB
# chromadb   ------------------------------ 563.54 KiB/613.62 KiB
# ipython    ------------------------------ 696.56 KiB/802.33 KiB
# langchain  ------------------------------ 142.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 821.69 KiB/1.03 MiB
# pygments   ------------------------------ 941.76 KiB/1.17 MiB
# snowflake-core ------------------------------ 430.91 KiB/1.48 MiB
# jedi       ------------------------------ 287.06 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/238)
# langsmith  ------------------------------ 32.00 KiB/304.50 KiB
# protobuf   ------------------------------ 77.69 KiB/312.18 KiB
# weaviate-client ------------------------------ 52.16 KiB/322.71 KiB
# yarl       ------------------------------ 159.75 KiB/336.08 KiB
# jiter      ------------------------------ 157.74 KiB/337.45 KiB
# tzdata     ------------------------------ 77.54 KiB/338.63 KiB
# rpds-py    ------------------------------ 224.85 KiB/372.36 KiB
# google-cloud-resource-manager ------------------------------ 286.79 KiB/375.13 KiB
# prompt-toolkit ------------------------------ 320.00 KiB/378.73 KiB
# langchain-core ------------------------------ 313.81 KiB/402.55 KiB
# openai     ------------------------------ 269.84 KiB/445.42 KiB
# pytz       ------------------------------ 204.20 KiB/496.10 KiB
# chromadb   ------------------------------ 563.54 KiB/613.62 KiB
# ipython    ------------------------------ 712.56 KiB/802.33 KiB
# langchain  ------------------------------ 158.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 840.56 KiB/1.03 MiB
# pygments   ------------------------------ 949.95 KiB/1.17 MiB
# snowflake-core ------------------------------ 430.91 KiB/1.48 MiB
# jedi       ------------------------------ 287.06 KiB/1.50 MiB
# aiohttp    ------------------------------ 846.88 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/238)
# qdrant-client ------------------------------ 31.89 KiB/299.45 KiB
# langsmith  ------------------------------ 88.91 KiB/304.50 KiB
# protobuf   ------------------------------ 125.69 KiB/312.18 KiB
# weaviate-client ------------------------------ 68.16 KiB/322.71 KiB
# yarl       ------------------------------ 187.66 KiB/336.08 KiB
# jiter      ------------------------------ 200.66 KiB/337.45 KiB
# tzdata     ------------------------------ 93.99 KiB/338.63 KiB
# rpds-py    ------------------------------ 270.48 KiB/372.36 KiB
# google-cloud-resource-manager ------------------------------ 334.79 KiB/375.13 KiB
# prompt-toolkit ------------------------------ 363.59 KiB/378.73 KiB
# langchain-core ------------------------------ 361.71 KiB/402.55 KiB
# openai     ------------------------------ 286.20 KiB/445.42 KiB
# pytz       ------------------------------ 220.20 KiB/496.10 KiB
# ipython    ------------------------------ 728.56 KiB/802.33 KiB
# langchain  ------------------------------ 190.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 880.28 KiB/1.03 MiB
# pygments   ------------------------------ 992.45 KiB/1.17 MiB
# snowflake-core ------------------------------ 494.91 KiB/1.48 MiB
# jedi       ------------------------------ 287.06 KiB/1.50 MiB
# aiohttp    ------------------------------ 881.12 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/238)
# qdrant-client ------------------------------ 31.89 KiB/299.45 KiB
# langsmith  ------------------------------ 88.91 KiB/304.50 KiB
# protobuf   ------------------------------ 125.69 KiB/312.18 KiB
# weaviate-client ------------------------------ 68.16 KiB/322.71 KiB
# yarl       ------------------------------ 191.75 KiB/336.08 KiB
# jiter      ------------------------------ 216.66 KiB/337.45 KiB
# tzdata     ------------------------------ 93.99 KiB/338.63 KiB
# rpds-py    ------------------------------ 286.48 KiB/372.36 KiB
# google-cloud-resource-manager ------------------------------ 334.79 KiB/375.13 KiB
# prompt-toolkit ------------------------------ 378.73 KiB/378.73 KiB
# langchain-core ------------------------------ 361.71 KiB/402.55 KiB
# openai     ------------------------------ 286.20 KiB/445.42 KiB
# pytz       ------------------------------ 220.20 KiB/496.10 KiB
# ipython    ------------------------------ 728.56 KiB/802.33 KiB
# langchain  ------------------------------ 190.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 880.28 KiB/1.03 MiB
# pygments   ------------------------------ 1006.08 KiB/1.17 MiB
# snowflake-core ------------------------------ 494.91 KiB/1.48 MiB
# jedi       ------------------------------ 303.06 KiB/1.50 MiB
# aiohttp    ------------------------------ 884.40 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (13/238)
# qdrant-client ------------------------------ 31.89 KiB/299.45 KiB
# langsmith  ------------------------------ 88.91 KiB/304.50 KiB
# protobuf   ------------------------------ 125.69 KiB/312.18 KiB
# weaviate-client ------------------------------ 68.16 KiB/322.71 KiB
# yarl       ------------------------------ 191.75 KiB/336.08 KiB
# jiter      ------------------------------ 216.66 KiB/337.45 KiB
# tzdata     ------------------------------ 93.99 KiB/338.63 KiB
# rpds-py    ------------------------------ 286.48 KiB/372.36 KiB
# google-cloud-resource-manager ------------------------------ 334.79 KiB/375.13 KiB
# langchain-core ------------------------------ 361.71 KiB/402.55 KiB
# openai     ------------------------------ 286.20 KiB/445.42 KiB
# pytz       ------------------------------ 220.20 KiB/496.10 KiB
# ipython    ------------------------------ 728.56 KiB/802.33 KiB
# langchain  ------------------------------ 190.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 880.28 KiB/1.03 MiB
# pygments   ------------------------------ 1006.08 KiB/1.17 MiB
# snowflake-core ------------------------------ 494.91 KiB/1.48 MiB
# jedi       ------------------------------ 303.06 KiB/1.50 MiB
# aiohttp    ------------------------------ 884.40 KiB/1.60 MiB
# networkx   ------------------------------ 569.29 KiB/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (13/238)
# bcrypt     ------------------------------ 32.00 KiB/272.08 KiB
# pypdf      ------------------------------ 31.85 KiB/291.69 KiB
# qdrant-client ------------------------------ 80.00 KiB/299.45 KiB
# langsmith  ------------------------------ 144.00 KiB/304.50 KiB
# protobuf   ------------------------------ 173.69 KiB/312.18 KiB
# weaviate-client ------------------------------ 80.00 KiB/322.71 KiB
# yarl       ------------------------------ 239.65 KiB/336.08 KiB
# jiter      ------------------------------ 253.74 KiB/337.45 KiB
# tzdata     ------------------------------ 93.99 KiB/338.63 KiB
# rpds-py    ------------------------------ 334.59 KiB/372.36 KiB
# google-cloud-resource-manager ------------------------------ 366.79 KiB/375.13 KiB
# openai     ------------------------------ 302.20 KiB/445.42 KiB
# pytz       ------------------------------ 220.20 KiB/496.10 KiB
# ipython    ------------------------------ 760.56 KiB/802.33 KiB
# langchain  ------------------------------ 206.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 936.56 KiB/1.03 MiB
# pygments   ------------------------------ 1.01 MiB/1.17 MiB
# snowflake-core ------------------------------ 510.91 KiB/1.48 MiB
# jedi       ------------------------------ 303.06 KiB/1.50 MiB
# aiohttp    ------------------------------ 926.88 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (13/238)
# bcrypt     ------------------------------ 32.00 KiB/272.08 KiB
# pypdf      ------------------------------ 31.85 KiB/291.69 KiB
# qdrant-client ------------------------------ 80.00 KiB/299.45 KiB
# langsmith  ------------------------------ 144.00 KiB/304.50 KiB
# protobuf   ------------------------------ 173.69 KiB/312.18 KiB
# weaviate-client ------------------------------ 80.00 KiB/322.71 KiB
# yarl       ------------------------------ 239.65 KiB/336.08 KiB
# jiter      ------------------------------ 253.74 KiB/337.45 KiB
# tzdata     ------------------------------ 93.99 KiB/338.63 KiB
# rpds-py    ------------------------------ 334.59 KiB/372.36 KiB
# openai     ------------------------------ 302.20 KiB/445.42 KiB
# pytz       ------------------------------ 220.20 KiB/496.10 KiB
# ipython    ------------------------------ 760.56 KiB/802.33 KiB
# langchain  ------------------------------ 206.92 KiB/985.93 KiB
# tiktoken   ------------------------------ 936.56 KiB/1.03 MiB
# pygments   ------------------------------ 1.01 MiB/1.17 MiB
# snowflake-core ------------------------------ 510.91 KiB/1.48 MiB
# jedi       ------------------------------ 303.06 KiB/1.50 MiB
# aiohttp    ------------------------------ 926.88 KiB/1.60 MiB
# networkx   ------------------------------ 792.56 KiB/1.64 MiB
# kubernetes ------------------------------ 824.56 KiB/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (13/238)
# cohere     ------------------------------     0 B/246.56 KiB
# frozenlist ------------------------------     0 B/268.43 KiB
# bcrypt     ------------------------------ 62.76 KiB/272.08 KiB
# pypdf      ------------------------------ 53.66 KiB/291.69 KiB
# ...
# lancedb    ------------------------------ 12.82 MiB/30.67 MiB
# pylance    ------------------------------ 11.24 MiB/36.55 MiB
# ⠴ Preparing packages... (230/238) 13.43 MiB/40.13 MiB
# pyright    ------------------------------ 4.56 MiB/5.34 MiB
# pandas     ------------------------------ 11.41 MiB/12.45 MiB
# uv         ------------------------------ 14.09 MiB/15.42 MiB
# numpy      ------------------------------ 13.42 MiB/17.41 MiB
# lancedb    ------------------------------ 12.82 MiB/30.67 MiB
# pylance    ------------------------------ 13.11 MiB/36.55 MiB
# ⠦ Preparing packages... (231/238) 13.93 MiB/40.13 MiB
# pyright    ------------------------------ 4.56 MiB/5.34 MiB
# pandas     ------------------------------ 11.41 MiB/12.45 MiB
# uv         ------------------------------ 14.68 MiB/15.42 MiB
# numpy      ------------------------------ 13.42 MiB/17.41 MiB
# lancedb    ------------------------------ 13.09 MiB/30.67 MiB
# pylance    ------------------------------ 13.66 MiB/36.55 MiB
# ⠦ Preparing packages... (231/238) 14.45 MiB/40.13 MiB
# pyright    ------------------------------ 4.56 MiB/5.34 MiB
# pandas     ------------------------------ 11.41 MiB/12.45 MiB
# uv         ------------------------------ 14.68 MiB/15.42 MiB
# numpy      ------------------------------ 13.52 MiB/17.41 MiB
# lancedb    ------------------------------ 13.09 MiB/30.67 MiB
# pylance    ------------------------------ 13.66 MiB/36.55 MiB
# ⠦ Preparing packages... (231/238) 14.45 MiB/40.13 MiB
# pyright    ------------------------------ 4.56 MiB/5.34 MiB
# pandas     ------------------------------ 11.41 MiB/12.45 MiB
# uv         ------------------------------ 14.78 MiB/15.42 MiB
# numpy      ------------------------------ 13.98 MiB/17.41 MiB
# lancedb    ------------------------------ 13.09 MiB/30.67 MiB
# pylance    ------------------------------ 13.66 MiB/36.55 MiB
# ⠦ Preparing packages... (231/238) 14.45 MiB/40.13 MiB
# pyright    ------------------------------ 4.56 MiB/5.34 MiB
# pandas     ------------------------------ 11.41 MiB/12.45 MiB
# uv         ------------------------------ 15.00 MiB/15.42 MiB
# numpy      ------------------------------ 15.33 MiB/17.41 MiB
# lancedb    ------------------------------ 13.18 MiB/30.67 MiB
# pylance    ------------------------------ 13.66 MiB/36.55 MiB
# ⠦ Preparing packages... (231/238) 14.45 MiB/40.13 MiB
# pyright    ------------------------------ 4.57 MiB/5.34 MiB
# pandas     ------------------------------ 11.41 MiB/12.45 MiB
# uv         ------------------------------ 15.00 MiB/15.42 MiB
# numpy      ------------------------------ 15.82 MiB/17.41 MiB
# lancedb    ------------------------------ 15.67 MiB/30.67 MiB
# pylance    ------------------------------ 14.80 MiB/36.55 MiB
# ⠧ Preparing packages... (231/238) 14.45 MiB/40.13 MiB
# pandas     ------------------------------ 11.41 MiB/12.45 MiB
# uv         ------------------------------ 15.00 MiB/15.42 MiB
# numpy      ------------------------------ 16.37 MiB/17.41 MiB
# lancedb    ------------------------------ 15.67 MiB/30.67 MiB
# pylance    ------------------------------ 15.44 MiB/36.55 MiB
# ⠧ Preparing packages... (231/238) 14.45 MiB/40.13 MiB
# pandas     ------------------------------ 11.41 MiB/12.45 MiB
# uv         ------------------------------ 15.00 MiB/15.42 MiB
# numpy      ------------------------------ 17.39 MiB/17.41 MiB
# lancedb    ------------------------------ 15.67 MiB/30.67 MiB
# pylance    ------------------------------ 17.74 MiB/36.55 MiB
# ⠧ Preparing packages... (231/238) 14.45 MiB/40.13 MiB
# pandas     ------------------------------ 11.41 MiB/12.45 MiB
# uv         ------------------------------ 15.00 MiB/15.42 MiB
# lancedb    ------------------------------ 15.67 MiB/30.67 MiB
# pylance    ------------------------------ 18.36 MiB/36.55 MiB
# ⠧ Preparing packages... (231/238) 14.45 MiB/40.13 MiB
# pandas     ------------------------------ 11.41 MiB/12.45 MiB
# uv         ------------------------------ 15.00 MiB/15.42 MiB
# lancedb    ------------------------------ 15.67 MiB/30.67 MiB
# pylance    ------------------------------ 22.06 MiB/36.55 MiB
# ⠧ Preparing packages... (231/238) 14.45 MiB/40.13 MiB
# pandas     ------------------------------ 11.41 MiB/12.45 MiB
# uv         ------------------------------ 15.00 MiB/15.42 MiB
# lancedb    ------------------------------ 15.67 MiB/30.67 MiB
# pylance    ------------------------------ 26.71 MiB/36.55 MiB
# ⠧ Preparing packages... (231/238) 14.45 MiB/40.13 MiB
# pandas     ------------------------------ 11.53 MiB/12.45 MiB
# uv         ------------------------------ 15.22 MiB/15.42 MiB
# lancedb    ------------------------------ 17.07 MiB/30.67 MiB
# pylance    ------------------------------ 28.32 MiB/36.55 MiB
# ⠇ Preparing packages... (233/238) 16.15 MiB/40.13 MiB
# pandas     ------------------------------ 11.53 MiB/12.45 MiB
# lancedb    ------------------------------ 18.90 MiB/30.67 MiB
# pylance    ------------------------------ 30.29 MiB/36.55 MiB
# ⠇ Preparing packages... (233/238) 16.99 MiB/40.13 MiB
# pandas     ------------------------------ 11.53 MiB/12.45 MiB
# lancedb    ------------------------------ 18.92 MiB/30.67 MiB
# pylance    ------------------------------ 30.29 MiB/36.55 MiB
# ⠇ Preparing packages... (233/238) 16.99 MiB/40.13 MiB
# pandas     ------------------------------ 11.53 MiB/12.45 MiB
# lancedb    ------------------------------ 18.92 MiB/30.67 MiB
# pylance    ------------------------------ 30.29 MiB/36.55 MiB
# ⠇ Preparing packages... (233/238) 16.99 MiB/40.13 MiB
# pandas     ------------------------------ 11.53 MiB/12.45 MiB
# lancedb    ------------------------------ 20.98 MiB/30.67 MiB
# pylance    ------------------------------ 30.29 MiB/36.55 MiB
# ⠇ Preparing packages... (233/238) 16.99 MiB/40.13 MiB
# pandas     ------------------------------ 11.53 MiB/12.45 MiB
# lancedb    ------------------------------ 21.25 MiB/30.67 MiB
# pylance    ------------------------------ 32.13 MiB/36.55 MiB
# ⠋ Preparing packages... (234/238) 16.99 MiB/40.13 MiB
# pandas     ------------------------------ 11.53 MiB/12.45 MiB
# lancedb    ------------------------------ 21.25 MiB/30.67 MiB
# pylance    ------------------------------ 32.90 MiB/36.55 MiB
# ⠋ Preparing packages... (234/238) 17.09 MiB/40.13 MiB
# lancedb    ------------------------------ 21.25 MiB/30.67 MiB
# pylance    ------------------------------ 32.90 MiB/36.55 MiB
# ⠋ Preparing packages... (234/238) 17.50 MiB/40.13 MiB
# lancedb    ------------------------------ 21.25 MiB/30.67 MiB
# pylance    ------------------------------ 32.90 MiB/36.55 MiB
# ⠋ Preparing packages... (234/238) 17.52 MiB/40.13 MiB
# lancedb    ------------------------------ 21.27 MiB/30.67 MiB
# pylance    ------------------------------ 32.90 MiB/36.55 MiB
# ⠙ Preparing packages... (235/238) 19.23 MiB/40.13 MiB
# lancedb    ------------------------------ 23.18 MiB/30.67 MiB
# pylance    ------------------------------ 32.90 MiB/36.55 MiB
# ⠙ Preparing packages... (235/238) 19.23 MiB/40.13 MiB
# lancedb    ------------------------------ 23.18 MiB/30.67 MiB
# pylance    ------------------------------ 33.45 MiB/36.55 MiB
# ⠙ Preparing packages... (235/238) 19.23 MiB/40.13 MiB
# lancedb    ------------------------------ 23.18 MiB/30.67 MiB
# pylance    ------------------------------ 33.92 MiB/36.55 MiB
# ⠙ Preparing packages... (235/238) 19.26 MiB/40.13 MiB
# lancedb    ------------------------------ 23.24 MiB/30.67 MiB
# pylance    ------------------------------ 33.92 MiB/36.55 MiB
# ⠹ Preparing packages... (235/238) 20.87 MiB/40.13 MiB
# lancedb    ------------------------------ 24.02 MiB/30.67 MiB
# pylance    ------------------------------ 33.92 MiB/36.55 MiB
# ⠹ Preparing packages... (235/238) 20.87 MiB/40.13 MiB
# lancedb    ------------------------------ 25.96 MiB/30.67 MiB
# pylance    ------------------------------ 33.92 MiB/36.55 MiB
# ⠹ Preparing packages... (235/238) 20.87 MiB/40.13 MiB
# lancedb    ------------------------------ 28.60 MiB/30.67 MiB
# pylance    ------------------------------ 33.92 MiB/36.55 MiB
# ⠹ Preparing packages... (235/238) 20.87 MiB/40.13 MiB
# lancedb    ------------------------------ 28.81 MiB/30.67 MiB
# pylance    ------------------------------ 34.96 MiB/36.55 MiB
# ⠸ Preparing packages... (235/238) 20.87 MiB/40.13 MiB
# lancedb    ------------------------------ 29.06 MiB/30.67 MiB
# pylance    ------------------------------ 34.96 MiB/36.55 MiB
# ⠸ Preparing packages... (235/238) 20.87 MiB/40.13 MiB
# lancedb    ------------------------------ 29.06 MiB/30.67 MiB
# pylance    ------------------------------ 35.03 MiB/36.55 MiB
# ⠸ Preparing packages... (235/238) 20.87 MiB/40.13 MiB
# lancedb    ------------------------------ 29.06 MiB/30.67 MiB
# pylance    ------------------------------ 36.54 MiB/36.55 MiB
# ⠸ Preparing packages... (235/238) 21.88 MiB/40.13 MiB
# lancedb    ------------------------------ 29.06 MiB/30.67 MiB
# ⠸ Preparing packages... (235/238) 21.99 MiB/40.13 MiB
# lancedb    ------------------------------ 29.06 MiB/30.67 MiB
# ⠼ Preparing packages... (236/238) 24.09 MiB/40.13 MiB
# lancedb    ------------------------------ 30.07 MiB/30.67 MiB
# ⠴ Preparing packages... (236/238) 26.89 MiB/40.13 MiB
# lancedb    ------------------------------ 30.07 MiB/30.67 MiB
# ⠴ Preparing packages... (236/238) 26.89 MiB/40.13 MiB
# lancedb    ------------------------------ 30.12 MiB/30.67 MiB
# ⠴ Preparing packages... (236/238) 26.89 MiB/40.13 MiB
# lancedb    ------------------------------ 30.14 MiB/30.67 MiB
# ⠴ Preparing packages... (236/238) 26.89 MiB/40.13 MiB
# lancedb    ------------------------------ 30.15 MiB/30.67 MiB
# ⠴ Preparing packages... (236/238) 26.89 MiB/40.13 MiB
# ⠴ Preparing packages... (236/238) 28.80 MiB/40.13 MiB
# ⠴ Preparing packages... (236/238) 30.16 MiB/40.13 MiB
# ⠴ Preparing packages... (236/238) 35.05 MiB/40.13 MiB
# ⠴ Preparing packages... (236/238) 38.56 MiB/40.13 MiB
# Prepared 238 packages in 8.21s
# Installed 238 packages in 264mst0
#  + aiohappyeyeballs==2.4.4
#  + aiohttp==3.11.11
#  + aiosignal==1.3.2
#  + alembic==1.14.1
#  + annotated-types==0.7.0
#  + anyio==4.8.0
#  + appdirs==1.4.4
#  + asgiref==3.8.1
#  + asn1crypto==1.5.1
#  + asttokens==3.0.0
#  + atpublic==5.1
#  + attrs==25.1.0
#  + auth0-python==4.7.2
#  + authlib==1.3.1
#  + backoff==2.2.1
#  + bcrypt==4.2.1
#  + beautifulsoup4==4.12.3
#  + blinker==1.9.0
#  + build==1.2.2.post1
#  + cachetools==5.5.1
#  + certifi==2024.12.14
#  + cffi==1.17.1
#  + charset-normalizer==3.4.1
#  + chroma-hnswlib==0.7.6
#  + chromadb==0.5.23
#  + click==8.1.8
#  + cohere==5.13.11
#  + coloredlogs==15.0.1
#  + crewai==0.98.0
#  + crewai-tools==0.32.1
#  + cryptography==43.0.3
#  + dataclasses-json==0.6.7
#  + decorator==5.1.1
#  + deprecated==1.2.17
#  + deprecation==2.1.0
#  + distro==1.9.0
#  + docker==7.1.0
#  + docstring-parser==0.16
#  + docx2txt==0.8
#  + durationpy==0.9
#  + embedchain==0.1.126
#  + et-xmlfile==2.0.0
#  + executing==2.2.0
#  + fastapi==0.115.7
#  + fastavro==1.10.0
#  + filelock==3.17.0
#  + flatbuffers==25.1.24
#  + frozenlist==1.5.0
#  + fsspec==2024.12.0
#  + google-api-core==2.24.0
#  + google-auth==2.38.0
#  + google-cloud-aiplatform==1.78.0
#  + google-cloud-bigquery==3.29.0
#  + google-cloud-core==2.4.1
#  + google-cloud-resource-manager==1.14.0
#  + google-cloud-storage==2.19.0
#  + google-crc32c==1.6.0
#  + google-resumable-media==2.7.2
#  + googleapis-common-protos==1.66.0
#  + gptcache==0.1.44
#  + greenlet==3.1.1
#  + grpc-google-iam-v1==0.14.0
#  + grpcio==1.70.0
#  + grpcio-health-checking==1.70.0
#  + grpcio-status==1.70.0
#  + grpcio-tools==1.70.0
#  + h11==0.14.0
#  + h2==4.1.0
#  + hpack==4.1.0
#  + httpcore==1.0.7
#  + httptools==0.6.4
#  + httpx==0.27.2
#  + httpx-sse==0.4.0
#  + huggingface-hub==0.27.1
#  + humanfriendly==10.0
#  + hyperframe==6.1.0
#  + idna==3.10
#  + ijson==3.3.0
#  + importlib-metadata==8.5.0
#  + importlib-resources==6.5.2
#  + instructor==1.7.2
#  + ipython==8.31.0
#  + jedi==0.19.2
#  + jinja2==3.1.5
#  + jiter==0.8.2
#  + json-repair==0.35.0
#  + jsonpatch==1.33
#  + jsonpickle==4.0.1
#  + jsonpointer==3.0.0
#  + jsonref==1.1.0
#  + jsonschema==4.23.0
#  + jsonschema-specifications==2024.10.1
#  + kubernetes==32.0.0
#  + lancedb==0.18.0
#  + langchain==0.3.15
#  + langchain-cohere==0.3.5
#  + langchain-community==0.3.15
#  + langchain-core==0.3.31
#  + langchain-experimental==0.3.4
#  + langchain-openai==0.2.14
#  + langchain-text-splitters==0.3.5
#  + langsmith==0.1.147
#  + linkup-sdk==0.2.2
#  + litellm==1.57.4
#  + mako==1.3.8
#  + markdown-it-py==3.0.0
#  + markupsafe==3.0.2
#  + marshmallow==3.26.0
#  + matplotlib-inline==0.1.7
#  + mdurl==0.1.2
#  + mem0ai==0.1.48
#  + mmh3==5.1.0
#  + monotonic==1.6
#  + mpmath==1.3.0
#  + multidict==6.1.0
#  + mypy-extensions==1.0.0
#  + networkx==3.4.2
#  + new-project==0.1.0 (from file:///home/jovyan/work/L13/new_project)
#  + nodeenv==1.9.1
#  + numpy==1.26.4
#  + oauthlib==3.2.2
#  + onnxruntime==1.20.1
#  + openai==1.60.1
#  + openpyxl==3.1.5
#  + opentelemetry-api==1.29.0
#  + opentelemetry-exporter-otlp-proto-common==1.29.0
#  + opentelemetry-exporter-otlp-proto-grpc==1.29.0
#  + opentelemetry-exporter-otlp-proto-http==1.29.0
#  + opentelemetry-instrumentation==0.50b0
#  + opentelemetry-instrumentation-asgi==0.50b0
#  + opentelemetry-instrumentation-fastapi==0.50b0
#  + opentelemetry-proto==1.29.0
#  + opentelemetry-sdk==1.29.0
#  + opentelemetry-semantic-conventions==0.50b0
#  + opentelemetry-util-http==0.50b0
#  + orjson==3.10.15
#  + outcome==1.3.0.post0
#  + overrides==7.7.0
#  + packaging==24.2
#  + pandas==2.2.3
#  + parso==0.8.4
#  + patronus==0.0.17
#  + pdfminer-six==20231228
#  + pdfplumber==0.11.5
#  + pexpect==4.9.0
#  + pillow==11.1.0
#  + platformdirs==4.3.6
#  + portalocker==2.10.1
#  + posthog==3.10.0
#  + prompt-toolkit==3.0.50
#  + propcache==0.2.1
#  + proto-plus==1.25.0
#  + protobuf==5.29.3
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyarrow==19.0.0
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.1
#  + pycparser==2.22
#  + pydantic==2.10.6
#  + pydantic-core==2.27.2
#  + pydantic-settings==2.7.1
#  + pygments==2.19.1
#  + pyjwt==2.10.1
#  + pylance==0.22.0
#  + pyopenssl==24.3.0
#  + pypdf==5.2.0
#  + pypdfium2==4.30.1
#  + pypika==0.48.9
#  + pyproject-hooks==1.2.0
#  + pyright==1.1.392.post0
#  + pysbd==0.3.4
#  + pysocks==1.7.1
#  + python-dateutil==2.9.0.post0
#  + python-dotenv==1.0.1
#  + pytube==15.0.0
#  + pytz==2024.2
#  + pyvis==0.3.2
#  + pyyaml==6.0.2
#  + qdrant-client==1.13.2
#  + referencing==0.36.2
#  + regex==2024.11.6
#  + requests==2.32.3
#  + requests-oauthlib==2.0.0
#  + requests-toolbelt==1.0.0
#  + rich==13.9.4
#  + rpds-py==0.22.3
#  + rsa==4.9
#  + schema==0.7.7
#  + scrapegraph-py==1.10.2
#  + selenium==4.28.1
#  + serpapi==0.1.5
#  + setuptools==75.8.0
#  + shapely==2.0.6
#  + shellingham==1.5.4
#  + six==1.17.0
#  + sniffio==1.3.1
#  + snowflake==1.0.2
#  + snowflake-connector-python==3.13.0
#  + snowflake-core==1.0.2
#  + snowflake-legacy==1.0.0
#  + sortedcontainers==2.4.0
#  + soupsieve==2.6
#  + spider-client==0.1.26
#  + sqlalchemy==2.0.37
#  + stack-data==0.6.3
#  + starlette==0.45.3
#  + sympy==1.13.3
#  + tabulate==0.9.0
#  + tenacity==9.0.0
#  + tiktoken==0.7.0
#  + tokenizers==0.20.3
#  + tomli==2.2.1
#  + tomli-w==1.2.0
#  + tomlkit==0.13.2
#  + tqdm==4.67.1
#  + traitlets==5.14.3
#  + trio==0.28.0
#  + trio-websocket==0.11.1
#  + typer==0.15.1
#  + types-requests==2.32.0.20241016
#  + typing-extensions==4.12.2
#  + typing-inspect==0.9.0
#  + tzdata==2025.1
#  + urllib3==2.3.0
#  + uv==0.5.24
#  + uvicorn==0.34.0
#  + uvloop==0.21.0
#  + validators==0.34.0
#  + watchfiles==1.0.4
#  + wcwidth==0.2.13
#  + weaviate-client==4.10.4
#  + websocket-client==1.8.0
#  + websockets==14.2
#  + wrapt==1.17.2
#  + wsproto==1.2.0
#  + yarl==1.18.3
#  + zipp==3.21.0

# %% [markdown]
# ## Setting Environment Variables

# %%
! cat new_project/.env
# Out:
# OPENAI_API_KEY=YOUR_API_KEY_HERE

# %% [markdown]
# ## Running the Crew

# %%
! cd new_project && crewai run
# Out:
# Running the Crew
# LLM value is None
# LLM value is None
# # Agent: AI LLMs Senior Data Researcher
# ## Task: Conduct a thorough research about AI LLMs Make sure you find any interesting and relevant information given the current year is 2024.
#
#
#
# # Agent: AI LLMs Senior Data Researcher
# ## Final Answer:
# 1. **GPT-4 Advancements**: In 2024, OpenAI's GPT-4 has received major upgrades, including improved context management and the ability to handle longer conversations and more complex queries, leading to increased effectiveness in conversational AI applications.
#
# 2. **Multimodal Capabilities**: AI LLMs have increasingly integrated multimodal functionalities, allowing them to process and generate text, images, and even audio, significantly broadening their application potential across various fields, such as education and entertainment.
#
# 3. **Bias Mitigation Efforts**: Researchers and developers are focusing on strategies to address biases in AI LLMs. New methodologies in training datasets aim to diversify input sources, thereby enhancing fairness and reducing unwanted biases in generated outputs.
#
# 4. **Performance Benchmarking**: As competition heats up, several AI LLMs have been benchmarked against each other in standardized tests, revealing performance improvements, especially in complex tasks like logical reasoning and creative writing.
#
# 5. **Federated Learning**: The adoption of federated learning in AI LLM training has become more prevalent. This method preserves user data privacy by allowing models to learn from decentralized data sources without transferring raw data to central servers, appealing to privacy-conscious applications.
#
# 6. **Customizable AI**: 2024 has seen an increase in customizable AI models, enabling businesses and individuals to tailor LLMs according to specific industry needs or personal preferences, which enhances user satisfaction and engagement.
#
# 7. **Collaborative AI Systems**: AI LLMs are increasingly used in collaborative systems where multiple models work in concert, allowing for richer and more context-aware interactions, specifically in customer support and virtual assistants.
#
# 8. **Integration in Software Tools**: Major software platforms are embedding AI LLMs into their tools (e.g., Microsoft Office's Copilot), enhancing productivity through advanced features like automated drafting, summarization, and data insights generation.
#
# 9. **Open Source Movement**: There is a significant push for open-source alternatives to proprietary AI LLMs, allowing developers and researchers to access, modify, and improve upon existing models, fostering innovation and transparency in the space.
#
# 10. **Regulatory Impacts**: Governments and regulatory bodies are becoming more involved in the deployment of AI LLMs, discussing potential accountability standards and ethical guidelines to ensure responsible use, which is shaping how companies implement these technologies.
#
#
# # Agent: AI LLMs Reporting Analyst
# ## Task: Review the context you got and expand each topic into a full section for a report. Make sure the report is detailed and contains any and all relevant information.
#
#
#
# # Agent: AI LLMs Reporting Analyst
# ## Final Answer:
# # Detailed Report on Current Trends in AI LLMs for 2024
#
# ## 1. GPT-4 Advancements
# In 2024, OpenAI’s GPT-4 has undergone significant enhancements aimed at improving the overall user experience and effectiveness of conversational AI. The core upgrades include advanced context management capabilities, which allow the model to maintain coherent threads over substantially longer dialogues. This improvement in conversation length enables more complex queries without losing focus or context, fostering more natural interactions between users and AI. These advancements not only enhance the user experience but also expand the model's utility in areas like customer support, education, and personal assistance, where sustained interactions can yield better outcomes.
#
# ## 2. Multimodal Capabilities
# The integration of multimodal functionalities in AI LLMs has become increasingly relevant, allowing these systems to process and generate not just text but also images and audio. This convergence significantly enhances application potential across various sectors, including education, where interactive learning materials can be developed, and entertainment, where immersive experiences can be created. The use of multimodal inputs allows for richer data interpretation, providing users with a more comprehensive understanding and diversified engagement methods, such as generating illustrative content alongside textual explanations.
#
# ## 3. Bias Mitigation Efforts
# Addressing biases in AI LLMs continues to be a significant research focus. In 2024, innovative strategies are being employed to diversify training datasets, encompassing a wide array of voices and perspectives. By ensuring that input sources are varied, researchers aim to enhance fairness in model outputs. Efforts include implementing more sophisticated algorithms to detect bias and creating mechanisms for users to report and refine outputs that may inadvertently perpetuate stereotypes. This holistic approach not only enhances the ethical standing of AI models but also improves their acceptance and reliability across different demographic segments.
#
# ## 4. Performance Benchmarking
# As competition amongst AI LLMs intensifies, various models have been subjected to stringent performance benchmarking against standardized tests. The results show notable improvements in handling complex tasks, including logical reasoning, nuanced understanding of language, and creative writing. These benchmarks help guide development priorities and enable users to select models based on concrete performance metrics. Consequently, organizations can make informed decisions about which AI LLM best meets their needs, whether for content generation, summarization, or analytical tasks.
#
# ## 5. Federated Learning
# Federated learning is gaining traction as a preferred methodology for AI LLM training in order to bolster data privacy. This innovative approach allows models to learn from user data residing on local devices without the need to transfer it to central servers. By updating the models locally and sharing only the model updates, federated learning assures privacy-conscious stakeholders that sensitive information remains on their devices. As a result, organizations find it appealing for applications that require stringent data protection measures, fostering user trust in AI systems.
#
# ## 6. Customizable AI
# The trend toward customizable AI models has seen considerable growth in 2024. Businesses and individuals can tailor AI LLMs to fit specific industry requirements or personal preferences, enhancing user satisfaction and engagement. Customizations range from modifying language styles to integrating industry-specific knowledge bases. This flexibility allows users to derive maximum value from AI interactions, ensuring that AI LLMs feel more relevant and applicable to their unique contexts, be it in healthcare, finance, or creative arts.
#
# ## 7. Collaborative AI Systems
# The development of collaborative AI systems is reshaping the landscape of AI LLM application. Multiple models are now designed to work collaboratively, enhancing interaction capabilities in fields such as customer support and virtual assistance. These systems can provide more context-aware responses and address multifaceted user queries by leveraging the strengths of different models. This collaborative approach not only improves response accuracy but also enriches the user experience, creating a more seamless and helpful interaction framework.
#
# ## 8. Integration in Software Tools
# The integration of AI LLMs into major software tools, exemplified by platforms like Microsoft Office’s Copilot, is revolutionizing productivity. These advanced models now assist users in drafting documents, summarizing content, and generating insightful data analyses. With these integrations, users benefit from enhanced efficiency and creativity in their workflows. This direct embedding of LLM capabilities into everyday software applications underscores the vital role of AI in streamlining various tasks, ultimately enhancing business outcomes and individual productivity.
#
# ## 9. Open Source Movement
# The push for open-source alternatives to proprietary AI LLMs has gained momentum, providing developers and researchers with more opportunities to explore, customize, and improve upon existing models. This movement promotes transparency and inclusivity within the field, encouraging collaborative innovation across the AI community. By accessing open-source models, startups and academic institutions can iterate on established frameworks and contribute to the enhancement of AI technologies without the constraints of licensing fees, further democratizing the tech landscape.
#
# ## 10. Regulatory Impacts
# In 2024, the engagement of governments and regulatory bodies in the deployment of AI LLMs has become increasingly prevalent. Discussions around accountability standards and ethical guidelines are shaping how companies implement these technologies. This regulatory focus aims to ensure responsible use of AI, balancing technological advancement with societal values. Companies are now more vigilant about compliance, fostering a culture of responsibility and ethics in their AI initiatives. As such, the accountability measures are poised to cultivate trust in AI systems, ultimately benefiting users and developers alike.
#
# This report encapsulates the key trends and advancements in AI LLMs for 2024, highlighting their implications across various sectors and prompting further exploration into their capabilities and responsible utilization.

# %% [markdown]
# ## Flows CLI - Command Line Interface

# %%
! crewai create flow new_flow
# Out:
# Creating flow new_flow...
# Flow new_flow created successfully!

# %%
! ls -1 new_flow
# Out:
# README.md
# pyproject.toml
# src
# tests

# %%
! ls -1 new_flow/src/new_flow/
# Out:
# __init__.py
# crews
# main.py
# tools
